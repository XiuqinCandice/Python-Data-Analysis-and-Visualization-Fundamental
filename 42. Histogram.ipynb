# %%
# Standard
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#Stats
from scipy import stats

# %%
# Plotting
import  matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
# allows us to see our plots in IP[y]: Notebook

# %%
url = 'http://en.wikipedia.org/wiki/Histogram'
#know histogram

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
#10 bins if the default number of bins that plt.hist() will create.
# Out:
# (array([ 2.,  1.,  6., 13., 26., 18., 16.,  7.,  7.,  4.]),
#  array([-2.90517797, -2.35402093, -1.8028639 , -1.25170686, -0.70054983,
#         -0.14939279,  0.40176424,  0.95292128,  1.50407832,  2.05523535,
#          2.60639239]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(70)
plt.hist(dataset2,color='indianred')
# Out:
# (array([ 1.,  1.,  6.,  5.,  7., 14., 13., 13.,  6.,  4.]),
#  array([-2.8008761 , -2.3150562 , -1.8292363 , -1.3434164 , -0.85759651,
#         -0.37177661,  0.11404329,  0.59986319,  1.08568308,  1.57150298,
#          2.05732288]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,density=True,color = 'indianred',alpha=0.5,bins=20)
plt.hist(dataset2, density=True,alpha=0.78,bins=20)
#alpha to control transparency
# Out:
# (array([0.05881074, 0.        , 0.05881074, 0.        , 0.29405371,
#         0.05881074, 0.11762148, 0.17643223, 0.29405371, 0.11762148,
#         0.41167519, 0.41167519, 0.41167519, 0.35286445, 0.58810742,
#         0.17643223, 0.29405371, 0.05881074, 0.11762148, 0.11762148]),
#  array([-2.8008761 , -2.55796615, -2.3150562 , -2.07214625, -1.8292363 ,
#         -1.58632635, -1.3434164 , -1.10050645, -0.85759651, -0.61468656,
#         -0.37177661, -0.12886666,  0.11404329,  0.35695324,  0.59986319,
#          0.84277313,  1.08568308,  1.32859303,  1.57150298,  1.81441293,
#          2.05732288]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')
