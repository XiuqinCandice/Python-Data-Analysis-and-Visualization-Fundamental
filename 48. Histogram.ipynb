# %%
# Standard
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#Status
from scipy import stats

# %%
#Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
#allow us to see plots in ipython notebook

# %%
url = 'http://en.wikipedia.org/wiki/Histogram'

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
#10 bins is the default number of bins
# Out:
# (array([ 2.,  7., 14.,  9., 16., 19., 13.,  8.,  8.,  4.]),
#  array([-1.88893273, -1.49682283, -1.10471293, -0.71260303, -0.32049313,
#          0.07161677,  0.46372667,  0.85583657,  1.24794647,  1.64005637,
#          2.03216627]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2,color='indianred')
# Out:
# (array([ 3.,  2.,  7., 17., 12., 10., 15.,  4.,  5.,  5.]),
#  array([-2.17980859, -1.73462229, -1.28943599, -0.84424969, -0.39906339,
#          0.04612291,  0.49130921,  0.93649551,  1.38168181,  1.82686812,
#          2.27205442]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,normed=True,alpha=0.5,bins=20)
#alpha is to change the transparency
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# (array([0.05615627, 0.11231253, 0.05615627, 0.05615627, 0.05615627,
#         0.33693759, 0.50540639, 0.44925012, 0.22462506, 0.44925012,
#         0.11231253, 0.44925012, 0.56156265, 0.28078133, 0.1684688 ,
#         0.05615627, 0.22462506, 0.05615627, 0.05615627, 0.22462506]),
#  array([-2.17980859, -1.95721544, -1.73462229, -1.51202914, -1.28943599,
#         -1.06684284, -0.84424969, -0.62165654, -0.39906339, -0.17647024,
#          0.04612291,  0.26871606,  0.49130921,  0.71390236,  0.93649551,
#          1.15908866,  1.38168181,  1.60427497,  1.82686812,  2.04946127,
#          2.27205442]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)

# %%
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')
