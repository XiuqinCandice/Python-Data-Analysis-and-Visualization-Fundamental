# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
np.random.seed(12345)

# %%
dframe = DataFrame(np.random.randn(1000,4))
#1000*4: 1000 rows/indexes 4 columns

# %%
dframe.head()
#check the first few rows
# Out:
#           0         1         2         3
# 0 -0.204708  0.478943 -0.519439 -0.555730
# 1  1.965781  1.393406  0.092908  0.281746
# 2  0.769023  1.246435  1.007189 -1.296221
# 3  0.274992  0.228913  1.352917  0.886429
# 4 -2.001637 -0.371843  1.669025 -0.438570

# %%
dframe.tail()
#check the last few rows
# Out:
#             0         1         2         3
# 995  1.089085  0.251232 -1.451985  1.653126
# 996 -0.478509 -0.010663 -1.060881 -1.502870
# 997 -1.946267  1.013592  0.037333  0.133304
# 998 -1.293122 -0.322542 -0.782960 -0.303340
# 999  0.089987  0.292291  1.177706  0.882755

# %%
dframe.describe()
#returns the statistic data
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.067684     0.067924     0.025598    -0.002298
# std       0.998035     0.992106     1.006835     0.996794
# min      -3.428254    -3.548824    -3.184377    -3.745356
# 25%      -0.774890    -0.591841    -0.641675    -0.644144
# 50%      -0.116401     0.101143     0.002073    -0.013611
# 75%       0.616366     0.780282     0.680391     0.654328
# max       3.366626     2.653656     3.260383     3.927528

# %%
#call the first column
col = dframe[0]
col.head()
# Out:
# 0   -0.204708
# 1    1.965781
# 2    0.769023
# 3    0.274992
# 4   -2.001637
# Name: 0, dtype: float64

# %%
col.head()
# Out:
# 0   -0.204708
# 1    1.965781
# 2    0.769023
# 3    0.274992
# 4   -2.001637
# Name: 0, dtype: float64

# %%
col[np.abs(col)>3]
#check which values in the column are greater than 3
#.abs() means absolute value is bigger to 3
# Out:
# 396   -3.108915
# Name: 0, dtype: float64

# %%
#meaning row 396, the absolute value is bigger than 3

# %%
#for all the columns
dframe[(np.abs(dframe)>3).any(1)]
#return every row that has value greater than 3
# Out:
#             0         1         2         3
# 46  -0.658090 -0.207434  3.525865  0.283070
# 67   0.599947 -3.645860  0.255475 -0.549574
# 289 -1.559625  0.336788 -3.333767 -1.240685
# 371 -1.116332 -3.018842 -0.298748  0.406954
# 396 -3.108915  1.117755 -0.152780 -0.340173
# 526  1.188742 -3.183867  1.050471 -1.042736
# 573 -2.214074 -3.140963 -1.509976 -0.389818
# 738 -0.088202  1.090038 -0.848098 -3.194414
# 768  0.474358  0.003349 -0.011807  3.023720
# 797  2.368010  0.452649 -3.481593  0.789944
# 966  0.164293  3.082067 -0.516982  0.251909
# 994 -0.843849  3.189940  0.070978  0.516982

# %%
dframe[(np.abs(dframe)>3)] = np.sign(dframe)*3
#.sign() just keep the integer part of the number. So all abstract number greater than 3 will be set to 3, sign will be  or -

# %%
dframe.describe()
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.020772     0.002361    -0.019163    -0.025951
# std       0.979685     1.021487     0.990725     0.959788
# min      -3.000000    -3.000000    -3.000000    -3.000000
# 25%      -0.697479    -0.697678    -0.694020    -0.700987
# 50%      -0.005279     0.031774    -0.014728    -0.038483
# 75%       0.618116     0.690065     0.651287     0.649747
# max       2.859053     3.000000     3.000000     3.000000
